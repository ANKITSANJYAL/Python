# %%
import numpy as np
import pandas as pd
import plotly as pl
import plotly.offline as po
import cufflinks as cf

# %%
po.init_notebook_mode(connected = True)
cf.go_offline()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.2.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.2.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
def createdata(data):
        if data == 1:
            x = np.random.rand(100,5)
            df1 = pd.DataFrame(data = x,columns = ['A','B','C','D','E'])
        elif data == 2:
            x  = [0,0,0,0,0]
            r1 = [0,0,0,0,0]
            r2 = [0,0,0,0,0]
            r3 = [0,0,0,0,0]
            r4 = [0,0,0,0,0]
            print("enter the values for columns name")
            i=0
            for i in [0,1,2,3,4]:
                x[i]=input()
                i=i+1

            print('enter the values for first row')
            i=0
            for i in [0,1,2,3,4]:
                r1[i]=int(input())
                i=i+1

            print('enter the values for second row')
            i=0
            for i in [0,1,2,3,4]:
                r2[i]=int(input())
                i=i+1

            print('enter the values for third row')
            i=0
            for i in [0,1,2,3,4]:
                r3[i]=int(input())
                i=i+1

            print('enter the values for fourth row')
            i=0
            for i in [0,1,2,3,4]:
                r4[i]=int(input())
                i=i+1
            df2 = pd.DataFrame(['r1','r2','r3','r4'],columns = x)
        elif data == 3:
            file = input("enter the file name")
            x = pd.read_csv(file)
            df1 = pd.DataFrame(x)
        
        else: 
            print('DATA FRAME CREATION FAILED')
        
        return df1

# %%
def plotter(plot):
    if plot == 1:
        final_output = df1.iplot(kind='scatter')
    elif plot ==2:
        final_output = df1.iplot(kind='scatter',mode='marker')
    elif plot ==3:
        final_output = df1.iplot(kind = 'bar')
    elif plot ==4:
        final_output = df1.iplot(kind = 'hist')
    elif plot ==5:
        final_output = df1.iplot(kind ='box')
    elif plot ==6:
        final_output = df1.iplot(kind = 'surface')
    else :
        final_output = print('enter the valid selection')
    return final_output

# %%
def plotter2(plot):
    col = input('Enter the number of columns you want to plot by selecting only 1 , 2 or 3')
    col = int(col)
    if(col==1):
        colm = input('Enter the column you want to plot by selecting any column from dataframe head')
        if(plot==1):
            finalplot = df1[colm].iplot(kind='scatter')
        elif(plot==2):
            finalplot = df1[colm].iplot(kind='scatter' , mode='markers' , symbol='x' ,colorscale='paired')
        elif(plot==3):
            finalplot = df1[colm].iplot(kind='bar')
        elif(plot==4):
            finalplot = df1[colm].iplot(kind='hist')
        elif(plot==5):
            finalplot = df1[colm].iplot(kind='box')
        elif(plot==6 or plot==7):
            finalplot = print('Bubble plot and surface plot require more than one column arguments')
        else:
            finalplot = print('Select only between 1 to 7')
    elif(col==2):
        print('Enter the columns you want to plot by selecting from dataframe head')
        x = input('First column')
        y = input('Second column')
        if(plot==1):
            finalplot = df1[[x,y]].iplot(kind='scatter')
        elif(plot==2):
            finalplot = df1[[x,y]].iplot(kind='scatter' , mode='markers' , symbol='x' ,colorscale='paired')
        elif(plot==3):
            finalplot = df1[[x,y]].iplot(kind='bar')
        elif(plot==4):
            finalplot = df1[[x,y]].iplot(kind='hist')
        elif(plot==5):
            finalplot = df1[[x,y]].iplot(kind='box')
        elif(plot==6):
            finalplot = df1[[x,y]].iplot(kind='surface')
        elif(plot==7):
            size = input('Please enter the size column for bubble plot')
            finalplot = df1.iplot(kind='bubble' , x=x,y=y,size=size)
        else:
            finalplot = print('Select only between 1 to 7')
    elif(col==3):
        print('Enter the columns you want to plot')
        x=input('First column')
        y=input('Second column')
        z=input('Third column')
        if(plot==1):
            finalplot = df1[[x,y,z]].iplot(kind='scatter')
        elif(plot==2):
            finalplot = df1[[x,y,z]].iplot(kind='scatter' , mode='markers' , symbol='x' ,colorscale='paired')
        elif(plot==3):
            finalplot = df1[[x,y,z]].iplot(kind='bar')
        elif(plot==4):
            finalplot = df1[[x,y,z]].iplot(kind='hist')
        elif(plot==5):
            finalplot = df1[[x,y,z]].iplot(kind='box')
        elif(plot==6):
            finalplot = df1[[x,y,z]].iplot(kind='surface')
        elif(plot==7):
            size = input('Please enter the size column for bubble plot')
            finalplot = df1.iplot(kind='bubble' , x=x,y=y,z=z,size=size )
        else:
            finalplot = print('Select only between 1 to 7')
    else:
        finalplot = print('Please enter only 1 , 2 or 3')
    return finalplot

# %%
def main(cat):
    if cat == 1:
        print('select the type of plot you want')
        print('1 for line plot')
        print('2 for scatter plot')
        print('3 for bar plot')
        print('4 for histogram')
        print('5 for box plot')
        print('6 for surface plot')
        plot = int(input())
        output = plotter(plot)
    elif cat ==2:
        print('select the type of plot you want')
        print('1 for line plot')
        print('2 for scatter plot')
        print('3 for bar plot')
        print('4 for histogram')
        print('5 for box plot')
        print('6 for surface plot')
        print('7 for bubble plot')
        plot = int(input())
        output = plotter2(plot)
    else: 
        print('please enter the valid selection')
        
        
    return output

# %%
print('-------------------welcome to the ploting area-------------------')
print('SELECT THE TYPE OF DATA YOU WANT TO PLOT')
print("------------------------------------------------------------------")
print('1. RANDOM DATA WITH 100 ROWS AND 5 COLUMNS')
print('2. CUSTOMIZED DATA WITH 4 ROWS AND 5 COLUMNS')
print('3 . UPLOAD CSV/JSON/TEXT FILE')
data = int(input())
df1 = createdata(data)
# Out:
# -------------------welcome to the ploting area-------------------
# SELECT THE TYPE OF DATA YOU WANT TO PLOT
# ------------------------------------------------------------------
# 1. RANDOM DATA WITH 100 ROWS AND 5 COLUMNS
# 2. CUSTOMIZED DATA WITH 4 ROWS AND 5 COLUMNS
# 3 . UPLOAD CSV/JSON/TEXT FILE
# 3
# enter the file name214.agri.csv

# %%
print('BELOW IS THE HEAD OF YOUR FATA WHICH WILL MAKE YOU EASY TO SELECT THE DATA OR SLICE OF DATA YOU WANT TO ANALYZE')
df1.head()
# Out:
# BELOW IS THE HEAD OF YOUR FATA WHICH WILL MAKE YOU EASY TO SELECT THE DATA OR SLICE OF DATA YOU WANT TO ANALYZE
#   code        state category  total exports   beef  pork  poultry   dairy  \
# 0   AL      Alabama    state        1390.63   34.4  10.6    481.0    4.06
# 1   AK       Alaska    state          13.31    0.2   0.1      0.0    0.19
# 2   AZ      Arizona    state        1463.17   71.3  17.9      0.0  105.48
# 3   AR     Arkansas    state        3586.02   53.2  29.4    562.9    3.53
# 4   CA   California    state       16472.88  228.7  11.1    225.4  929.95
#
#    fruits fresh  fruits proc  total fruits  veggies fresh  veggies proc  \
# 0           8.0         17.1         25.11            5.5           8.9
# 1           0.0          0.0          0.00            0.6           1.0
# 2          19.3         41.0         60.27          147.5         239.4
# 3           2.2          4.7          6.88            4.4           7.1
# 4        2791.8       5944.6       8736.40          803.2        1303.5
#
#    total veggies  corn  wheat   cotton  \
# 0          14.33  34.9   70.0   317.61
# 1           1.56   0.0    0.0     0.00
# 2         386.91   7.3   48.7   423.95
# 3          11.45  69.5  114.5   665.44
# 4        2106.79  34.6  249.3  1064.95
#
#                                                 text
# 0  Alabama<br>Beef 34.4 Dairy 4.06<br>Fruits 25.1...
# 1  Alaska<br>Beef 0.2 Dairy 0.19<br>Fruits 0.0 Ve...
# 2  Arizona<br>Beef 71.3 Dairy 105.48<br>Fruits 60...
# 3  Arkansas<br>Beef 53.2 Dairy 3.53<br>Fruits 6.8...
# 4   California<br>Beef 228.7 Dairy 929.95<br>Frui...

# %%
print('SELECT IF YOU WANT TO PLOT THE WHOLE DATA OR JUST SOME OF THE COLUMNS')
cat = int(input('--------1 FOR WHOLE DATA -----AND-------2 FOR SELECTING COLUMNS-----'))
# Out:
# SELECT IF YOU WANT TO PLOT THE WHOLE DATA OR JUST SOME OF THE COLUMNS
# --------1 FOR WHOLE DATA -----AND-------2 FOR SELECTING COLUMNS-----1

# %%
main(cat)
# Out:
# select the type of plot you want
# 1 for line plot
# 2 for scatter plot
# 3 for bar plot
# 4 for histogram
# 5 for box plot
# 6 for surface plot
# 6
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-37-67292d855ec6> in <module>
# ----> 1 main(cat)
#
# <ipython-input-32-f96829f5491a> in main(cat)
#       9         print('6 for surface plot')
#      10         plot = int(input())
# ---> 11         output = plotter(plot)
#      12     elif cat ==2:
#      13         print('select the type of plot you want')
#
# <ipython-input-30-cc742de433ad> in plotter(plot)
#      11         final_output = df1.iplot(kind ='box')
#      12     elif plot ==6:
# ---> 13         final_output = df1.iplot(kind = 'surface')
#      14     else :
#      15         final_output = print('enter the valid selection')
#
# ~\anaconda3\lib\site-packages\cufflinks\plotlytools.py in _iplot(self, kind, data, layout, filename, sharing, title, xTitle, yTitle, zTitle, theme, colors, colorscale, fill, width, dash, mode, interpolation, symbol, size, barmode, sortbars, bargap, bargroupgap, bins, histnorm, histfunc, orientation, boxpoints, annotations, keys, bestfit, bestfit_colors, mean, mean_colors, categories, x, y, z, text, gridcolor, zerolinecolor, margin, labels, values, secondary_y, secondary_y_title, subplots, shape, error_x, error_y, error_type, locations, lon, lat, asFrame, asDates, asFigure, asImage, dimensions, asPlot, asUrl, online, **kwargs)
#     964                                         zmax=max(z)
#     965                                 else:
# --> 966                                         zmin=z.min()
#     967                                         zmax=z.max()
#     968
#
# ~\anaconda3\lib\site-packages\numpy\core\_methods.py in _amin(a, axis, out, keepdims, initial, where)
#      32 def _amin(a, axis=None, out=None, keepdims=False,
#      33           initial=_NoValue, where=True):
# ---> 34     return umr_minimum(a, axis, None, out, keepdims, initial, where)
#      35
#      36 def _sum(a, axis=None, dtype=None, out=None, keepdims=False,
#
# TypeError: '<=' not supported between instances of 'str' and 'float'
